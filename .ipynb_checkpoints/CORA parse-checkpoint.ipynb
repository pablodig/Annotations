# %%
import requests
from requests_html import HTMLSession
from bs4 import BeautifulSoup
import json
import io
from PyPDF2 import PdfFileReader

# %%
# this function for the getting information from the web page

def get_paperinfo(paper_url):

    #download the page
    session = HTMLSession()
    response=session.get(paper_url)

  # check successful response
    if response.status_code != 200:
        print('Status code:', response.status_code)
        raise Exception('Failed to fetch web page ')

  #parse using beautiful soup
    paper_doc = BeautifulSoup(response.text,'html.parser')

    return paper_doc


def get_link(doc):
    
    link_tag = doc.find_all('h3',{"class" : "gs_rt"}) 
    
    paper_links = []
    paper_titles = []
  
    for link in link_tag:
        paper_links.append(link.a.get('href'))
        paper_titles.append(link.get_text())

    return paper_links, paper_titles

def info(pdf_path):

    # used get method to get the pdf file
    response = requests.get(pdf_path)
    # response.content generate binary code for
    # string function
    with io.BytesIO(response.content) as f:

        # initialized the pdf
        pdf = PdfFileReader(f)
        # all info about pdf
        information = pdf.getDocumentInfo()
        number_of_pages = pdf.getNumPages()

    txt = f"""
    Information about {pdf_path}:

    Author: {information.author}
    Creator: {information.creator}
    Producer: {information.producer}
    Subject: {information.subject}
    Title: {information.title}
    Number of pages: {number_of_pages}
    """
    print(txt)

    return information

# %%
# Getting information from Google Scholar
doc = get_paperinfo('https://scholar.google.com/scholar?start=0&q=RAB3&hl=es&as_sdt=0,5')

links, titles = get_link(doc)

links
# Out:
# ['https://www.annualreviews.org/doi/abs/10.1146/annurev.neuro.21.1.75',
#  'https://www.jneurosci.org/content/17/21/8061.short',
#  'https://www.cell.com/neuron/pdf/S0896-6273(00)80292-5.pdf',
#  'https://www.sciencedirect.com/science/article/pii/S0300908400002194',
#  'https://www.molbiolcell.org/doi/abs/10.1091/mbc.e05-12-1170',
#  'https://www.jneurosci.org/content/24/29/6629.short',
#  'https://onlinelibrary.wiley.com/doi/abs/10.1002/humu.22296',
#  'https://www.sciencedirect.com/science/article/pii/S0304394008011397',
#  'https://www.nature.com/articles/41580',
#  'https://www.sciencedirect.com/science/article/pii/S1044743110000655']

# %%
paper = get_paperinfo(links[1])
paper.find_all('h2')
# Out:
# [<h2 class="pane-title"><span class="icon-reorder"></span><span class="element-invisible">Main menu</span></h2>,
#  <h2 class="pane-title"><span class="icon-gear"></span><span class="element-invisible">User menu</span></h2>,
#  <h2 class="pane-title"><span class="icon-search"></span><span class="element-invisible">Search</span></h2>,
#  <h2>Abstract</h2>,
#  <h2 class="pane-title">In this issue</h2>,
#  <h2>Citation Manager Formats</h2>,
#  <h2 class="pane-title">Jump to section</h2>,
#  <h2 class="pane-title">Keywords</h2>,
#  <h2 class="pane-title">Responses to this article</h2>,
#  <h2 class="block-title">Content</h2>,
#  <h2 class="block-title">Information</h2>,
#  <h2 class="block-title"> About</h2>]

# %%
text = paper.find_all(text=True)
#print(text)
cleaned_text = ''
blacklist = [
        '[document]',
        'noscript',
        'header',
        'html',
        'meta',
        'head', 
        'input',
        'script',
        'style',]
for item in text:
#    if item.parent.name == 'h1':
#        print(item)
    print(item.parent.name)
    print(item)
    
#    print(item)
#    if item.parent.name not in blacklist:
#        cleaned_text += '{} '.format(item)
#cleaned_text = cleaned_text.replace('\t', '')
#print(cleaned_text)
#for t in cleaned_text:
 #   print(t)
    #for sentence in t.split('. '):
        #if 'Rab1b' in sentence:
     #   print(sentence)
# Out:
# [document]
# html
# [document]
#
#
# html
#
#
# head
#
#
# head
# [if IE]><![endif]
# head
#
#
# head
#
#
# head
#
#
# head
#
#
# head
#
#
# head
#
#
# head
#
#
# head
#
#
# head
#
#
# head
#
#
# head
#
#
# head
#
#
# head
#
#
# head
#
#
# head
#
#
# head
#
#
# head
#
#
# head
#
#
# head
#
#
# head
#
#
# head
#
#
# head
#
#
# head
#
#
# head
#
#
# head
#
#
# head
#
#
# head
#
#
# head
#
#
# head
#
#
# head
#
#
# head
#
#
# head
#
#
# head
#
#
# head
#
#
# head
#
#
# head
#
#
# head
#
#
# head
#
#
# head
#
#
# head
#
#
# head
#
#
# head
#
#
# head
#
#
# head
#
#
# head
#
#
# head
#
#
# head
#
#
# head
#
#
# head
#
#
# head
#
#
# head
#
#
# head
#
#
# head
#
#
# head
#
#
# head
#
#
# head
#
#
# head
#
#
# head
#
#
# head
#
#
# head
#
#
# head
#
#
# head
#
#
# head
#
#
# head
#
#
# head
#
#
# head
#
#
# head
#
#
# head
#
#
# head
#
#
# head
#
#
# head
#
#
# head
#
#
# head
#
#
# head
#
#
# head
#
#
# head
#
#
# head
#
#
# head
#
#
# head
#
#
# head
#
#
# head
#
#
# head
#
#
# head
#
#
# head
#
#
# head
#
#
# head
#
#
# head
#
#
# head
#
#
# head
#
#
# head
#
#
# head
#
#
# head
#
#
# head
#
#
# head
#
#
# head
#
#
# head
#
#
# head
#
#
# head
#
#
# head
#
#
# head
#
#
# head
#
#
# head
#
#
# head
#
#
# head
#
#
# head
#
#
# head
#
#
# head
#
#
# head
#
#
# head
#
#
# head
#
#
# head
#
#
# head
#
#
# head
#
#
# head
#
#
# head
#
#
# head
#
#
# head
#
#
# head
#
#
# head
#
#
# head
#
#
# head
#
#
# head
#
#
# head
#
#
# head
#
#
# head
#
#
# head
#
#
# head
#
#
# head
#
#
# head
#
#
# head
#
#
# head
#
#
# head
#
#
# head
#
#
# head
#
#
# head
#
#
# head
#
#
# head
#
#
# head
#
#
# head
#
#
# head
#
#
# head
#
#
# head
#
#
# head
#
#
# head
#
#
# head
#
#
# head
#
#
# head
#
#
# head
#
#
# head
#
#
# title
# Caenorhabditis elegans rab-3 Mutant Synapses Exhibit Impaired Function and Are Partially Depleted of Vesicles | Journal of Neuroscience
# head
#
#
# head
#
#
# head
#
#
# head
#
#
# style
#
# /* <![CDATA[ */
# #sliding-popup.sliding-popup-bottom,#sliding-popup.sliding-popup-bottom .eu-cookie-withdraw-banner,.eu-cookie-withdraw-tab{background:#104b7d}#sliding-popup.sliding-popup-bottom.eu-cookie-withdraw-wrapper{background:transparent}#sliding-popup .popup-content #popup-text h1,#sliding-popup .popup-content #popup-text h2,#sliding-popup .popup-content #popup-text h3,#sliding-popup .popup-content #popup-text p,.eu-cookie-compliance-secondary-button,.eu-cookie-withdraw-tab{color:#fff !important}.eu-cookie-withdraw-tab{border-color:#fff}.eu-cookie-compliance-more-button{color:#fff !important}
# /* ]]> */
#
# head
#
#
# head
# [if lte IE 7]>
# <link type="text/css" rel="stylesheet" href="https://www.jneurosci.org/sites/default/files/advagg_css/css__ElJr3PIJEvw3qLXc1cnYiLj2G4KgDPSXFOfm6Phf8hw__JdWGm15cDWjsK6KrFlQVXQix9YgNeYysf22XZHj-Y-c__fRkJcS2M2bCj0kIMBir98eX2gPii7eUHnT3JwRXgq1Q.css" media="all" />
# <![endif]
# head
#
#
# head
#
#
# head
#
#
# head
# [if (lt IE 9)&(!IEMobile)]>
# <link type="text/css" rel="stylesheet" href="https://www.jneurosci.org/sites/default/files/advagg_css/css__XH6bpcI0f2dImc-p674DLCZtWBGb-QwxJK1YexVGtno__vUceGprdo5nIhV6DH93X7fI3r8RcTJbChbas9TQXeW4__fRkJcS2M2bCj0kIMBir98eX2gPii7eUHnT3JwRXgq1Q.css" media="all" />
# <![endif]
# head
#
#
# head
# [if gte IE 9]><!
# head
#
#
# head
#
#
# head
# <![endif]
# head
#
#
# head
# [if gte IE 9]><!
# head
#
#
# head
#
#
# head
# <![endif]
# head
#
#
# head
#
#
# head
#
#
# head
#
#
# head
#
#
# head
#
#
# head
#
#
# head
#
#
# head
#
#
# head
#
#
# script
#
# <!--//--><![CDATA[//><!--
# /*!
#  * yepnope1.5.4
#  * (c) WTFPL, GPLv2
#  */
# (function(a,b,c){function d(a){return"[object Function]"==o.call(a)}function e(a){return"string"==typeof a}function f(){}function g(a){return!a||"loaded"==a||"complete"==a||"uninitialized"==a}function h(){var a=p.shift();q=1,a?a.t?m(function(){("c"==a.t?B.injectCss:B.injectJs)(a.s,0,a.a,a.x,a.e,1)},0):(a(),h()):q=0}function i(a,c,d,e,f,i,j){function k(b){if(!o&&g(l.readyState)&&(u.r=o=1,!q&&h(),l.onload=l.onreadystatechange=null,b)){"img"!=a&&m(function(){t.removeChild(l)},50);for(var d in y[c])y[c].hasOwnProperty(d)&&y[c][d].onload()}}var j=j||B.errorTimeout,l=b.createElement(a),o=0,r=0,u={t:d,s:c,e:f,a:i,x:j};1===y[c]&&(r=1,y[c]=[]),"object"==a?l.data=c:(l.src=c,l.type=a),l.width=l.height="0",l.onerror=l.onload=l.onreadystatechange=function(){k.call(this,r)},p.splice(e,0,u),"img"!=a&&(r||2===y[c]?(t.insertBefore(l,s?null:n),m(k,j)):y[c].push(l))}function j(a,b,c,d,f){return q=0,b=b||"j",e(a)?i("c"==b?v:u,a,b,this.i++,c,d,f):(p.splice(this.i++,0,a),1==p.length&&h()),this}function k(){var a=B;return a.loader={load:j,i:0},a}var l=b.documentElement,m=a.setTimeout,n=b.getElementsByTagName("script")[0],o={}.toString,p=[],q=0,r="MozAppearance"in l.style,s=r&&!!b.createRange().compareNode,t=s?l:n.parentNode,l=a.opera&&"[object Opera]"==o.call(a.opera),l=!!b.attachEvent&&!l,u=r?"object":l?"script":"img",v=l?"script":u,w=Array.isArray||function(a){return"[object Array]"==o.call(a)},x=[],y={},z={timeout:function(a,b){return b.length&&(a.timeout=b[0]),a}},A,B;B=function(a){function b(a){var a=a.split("!"),b=x.length,c=a.pop(),d=a.length,c={url:c,origUrl:c,prefixes:a},e,f,g;for(f=0;f<d;f++)g=a[f].split("="),(e=z[g.shift()])&&(c=e(c,g));for(f=0;f<b;f++)c=x[f](c);return c}function g(a,e,f,g,h){var i=b(a),j=i.autoCallback;i.url.split(".").pop().split("?").shift(),i.bypass||(e&&(e=d(e)?e:e[a]||e[g]||e[a.split("/").pop().split("?")[0]]),i.instead?i.instead(a,e,f,g,h):(y[i.url]?i.noexec=!0:y[i.url]=1,f.load(i.url,i.forceCSS||!i.forceJS&&"css"==i.url.split(".").pop().split("?").shift()?"c":c,i.noexec,i.attrs,i.timeout),(d(e)||d(j))&&f.load(function(){k(),e&&e(i.origUrl,h,g),j&&j(i.origUrl,h,g),y[i.url]=2})))}function h(a,b){function c(a,c){if(a){if(e(a))c||(j=function(){var a=[].slice.call(arguments);k.apply(this,a),l()}),g(a,j,b,0,h);else if(Object(a)===a)for(n in m=function(){var b=0,c;for(c in a)a.hasOwnProperty(c)&&b++;return b}(),a)a.hasOwnProperty(n)&&(!c&&!--m&&(d(j)?j=function(){var a=[].slice.call(arguments);k.apply(this,a),l()}:j[n]=function(a){return function(){var b=[].slice.call(arguments);a&&a.apply(this,b),l()}}(k[n])),g(a[n],j,b,n,h))}else!c&&l()}var h=!!a.test,i=a.load||a.both,j=a.callback||f,k=j,l=a.complete||f,m,n;c(h?a.yep:a.nope,!!i),i&&c(i)}var i,j,l=this.yepnope.loader;if(e(a))g(a,0,l,0);else if(w(a))for(i=0;i<a.length;i++)j=a[i],e(j)?g(j,0,l,0):w(j)?B(j):Object(j)===j&&h(j,l);else Object(a)===a&&h(a,l)},B.addPrefix=function(a,b){z[a]=b},B.addFilter=function(a){x.push(a)},B.errorTimeout=1e4,null==b.readyState&&b.addEventListener&&(b.readyState="loading",b.addEventListener("DOMContentLoaded",A=function(){b.removeEventListener("DOMContentLoaded",A,0),b.readyState="complete"},0)),a.yepnope=k(),a.yepnope.executeStack=h,a.yepnope.injectJs=function(a,c,d,e,i,j){var k=b.createElement("script"),l,o,e=e||B.errorTimeout;k.src=a;for(o in d)k.setAttribute(o,d[o]);c=j?h:c||f,k.onreadystatechange=k.onload=function(){!l&&g(k.readyState)&&(l=1,c(),k.onload=k.onreadystatechange=null)},m(function(){l||(l=1,c(1))},e),i?k.onload():n.parentNode.insertBefore(k,n)},a.yepnope.injectCss=function(a,c,d,e,g,i){var e=b.createElement("link"),j,c=i?h:c||f;e.href=a,e.rel="stylesheet",e.type="text/css";for(j in d)e.setAttribute(j,d[j]);g||(n.parentNode.insertBefore(e,n),m(c,0))}})(this,document);
#
# //--><!]]>
#
# head
#
#
# script
#
# <!--//--><![CDATA[//><!--
# yepnope({
#   test: Modernizr.matchmedia,
#   nope: '/sites/all/libraries/media-match/media.match.min.js'
# });
# //--><!]]>
#
# head
#
#
# script
#
# <!--//--><![CDATA[//><!--
# document.createElement( "picture" );
# //--><!]]>
#
# head
#
#
# script
#
# <!--//--><![CDATA[//><!--
# if(typeof window.MathJax === "undefined") window.MathJax = { menuSettings: { zoom: "Click" } };
# //--><!]]>
#
# head
#
#
# script
#
# <!--//--><![CDATA[//><!--
# (function(i,s,o,g,r,a,m){i["GoogleAnalyticsObject"]=r;i[r]=i[r]||function(){(i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)})(window,document,"script","//www.google-analytics.com/analytics.js","ga");ga("create", "UA-1707495-1", {"cookieDomain":"auto"});ga("set", "anonymizeIp", true);ga("send", "pageview");ga('create', 'UA-189672-46', 'auto', {'name': 'hwTracker'});
# ga('set', 'anonymizeIp', true);
# ga('hwTracker.send', 'pageview');
# //--><!]]>
#
# head
#
#
# script
#
# <!--//--><![CDATA[//><!--
# jQuery.extend(Drupal.settings,{"basePath":"\/","pathPrefix":"","ajaxPageState":{"theme":"jcore_1","theme_token":"E5bvezxX7vISrdWbcxw7RCUgg_Oy_ZlsN5PNFRNaxMk"},"colorbox":{"opacity":"0.85","current":"{current} of {total}","previous":"\u00ab Prev","next":"Next \u00bb","close":"Close","maxWidth":"98%","maxHeight":"98%","fixed":true,"mobiledetect":true,"mobiledevicewidth":"480px"},"highwire":{"nid":"354523","apath":"\/jneuro\/17\/21\/8061.atom","pisa":"jneuro;17\/21\/8061","ac":{"\/jneuro\/17\/21\/8061.atom":{"access":{"full":true,"abstract":true},"pisa_id":"","apath":"\/jneuro\/17\/21\/8061.atom","jcode":"jneuro"}},"processed":["highwire_math"],"markup":[{"requested":"short","variant":"abstract","view":"abstract","pisa":"jneuro;17\/21\/8061"},{"requested":"full-text","variant":"full-text","view":"full","pisa":"jneuro;17\/21\/8061"},{"requested":"full-text","variant":"full-text","view":"full","pisa":"jneuro;17\/21\/8061"}],"modal_window_width":"560","share_modal_width":"560","share_modal_title":"Share this Article","trendmd":{"trendmd-suggestions":"{\u0022element\u0022:\u0022#trendmd-suggestions\u0022,\u0022track_id\u0022:\u0022null\u0022}"}},"user_uid":0,"customer_email":null,"cartstack_siteid":"","foxycart_subdomain":"sn.ecommerce.highwire.org","foxycart_always_show_cart_link":true,"hw_fc_cookie_domain":".jneurosci.org","highwire_panel_tabs":[{"panel_name":"jnl_sfneneuro_tab_pdf","panel_ajax_tab":"jnl_sfneneuro_tab_pdf"}],"panel_ajax_tab":{"path":"sites\/all\/modules\/contrib\/panels_ajax_tab"},"instances":"{\u0022highwire_abstract_tooltip\u0022:{\u0022content\u0022:{\u0022text\u0022:\u0022\u0022},\u0022style\u0022:{\u0022tip\u0022:{\u0022width\u0022:20,\u0022height\u0022:20,\u0022border\u0022:1,\u0022offset\u0022:0,\u0022corner\u0022:true},\u0022classes\u0022:\u0022qtip-custom hw-tooltip hw-abstract-tooltip qtip-shadow qtip-rounded\u0022,\u0022classes_custom\u0022:\u0022hw-tooltip hw-abstract-tooltip\u0022},\u0022position\u0022:{\u0022at\u0022:\u0022right center\u0022,\u0022my\u0022:\u0022left center\u0022,\u0022viewport\u0022:true,\u0022adjust\u0022:{\u0022method\u0022:\u0022shift\u0022}},\u0022show\u0022:{\u0022event\u0022:\u0022mouseenter click \u0022,\u0022solo\u0022:true},\u0022hide\u0022:{\u0022event\u0022:\u0022mouseleave \u0022,\u0022fixed\u0022:1,\u0022delay\u0022:\u0022100\u0022}},\u0022highwire_author_tooltip\u0022:{\u0022content\u0022:{\u0022text\u0022:\u0022\u0022},\u0022style\u0022:{\u0022tip\u0022:{\u0022width\u0022:15,\u0022height\u0022:15,\u0022border\u0022:1,\u0022offset\u0022:0,\u0022corner\u0022:true},\u0022classes\u0022:\u0022qtip-custom hw-tooltip hw-author-tooltip qtip-shadow qtip-rounded\u0022,\u0022classes_custom\u0022:\u0022hw-tooltip hw-author-tooltip\u0022},\u0022position\u0022:{\u0022at\u0022:\u0022top center\u0022,\u0022my\u0022:\u0022bottom center\u0022,\u0022viewport\u0022:true,\u0022adjust\u0022:{\u0022method\u0022:\u0022\u0022}},\u0022show\u0022:{\u0022event\u0022:\u0022mouseenter \u0022,\u0022solo\u0022:true},\u0022hide\u0022:{\u0022event\u0022:\u0022mouseleave \u0022,\u0022fixed\u0022:1,\u0022delay\u0022:\u0022100\u0022}},\u0022highwire_reflinks_tooltip\u0022:{\u0022content\u0022:{\u0022text\u0022:\u0022\u0022},\u0022style\u0022:{\u0022tip\u0022:{\u0022width\u0022:15,\u0022height\u0022:15,\u0022border\u0022:1,\u0022mimic\u0022:\u0022top center\u0022,\u0022offset\u0022:0,\u0022corner\u0022:true},\u0022classes\u0022:\u0022qtip-custom hw-tooltip hw-ref-link-tooltip qtip-shadow qtip-rounded\u0022,\u0022classes_custom\u0022:\u0022hw-tooltip hw-ref-link-tooltip\u0022},\u0022position\u0022:{\u0022at\u0022:\u0022bottom left\u0022,\u0022my\u0022:\u0022top left\u0022,\u0022viewport\u0022:true,\u0022adjust\u0022:{\u0022method\u0022:\u0022flip\u0022}},\u0022show\u0022:{\u0022event\u0022:\u0022mouseenter \u0022,\u0022solo\u0022:true},\u0022hide\u0022:{\u0022event\u0022:\u0022mouseleave \u0022,\u0022fixed\u0022:1,\u0022delay\u0022:\u0022100\u0022}}}","qtipDebug":"{\u0022leaveElement\u0022:0}","urlIsAjaxTru ...
# //--><!]]>
#
# head
#
#
# head
# [if lt IE 9]><script src="http://html5shiv.googlecode.com/svn/trunk/html5.js"></script><![endif]
# head
#
#
# html
#
#
# body
#
#
# body
#  Google Tag Manager
# body
#
#
# body
#
#
# script
# (function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0];var j=d.createElement(s);var dl=l!='dataLayer'?'&l='+l:'';j.src='//www.googletagmanager.com/gtm.js?id='+i+dl;j.type='text/javascript';j.async=true;f.parentNode.insertBefore(j,f);})(window,document,'script','dataLayer','GTM-5VL3Q4C');
# body
#
#
# body
#  End Google Tag Manager
# body
#
#
# div
#
#
# a
# Skip to main content
# div
#
#
# body
#
#
# div
#
#
# header
#
#
# div
#
#
# div
#
#
# div
#
#
# div
#
#
# div
#
#
# div
#
#
# div
#
#
# div
#
#
# div
#
#
# div
#
#
# span
# Main menu
# div
#
#
# div
#
#
# div
#
#
# div
#
#
# div
#
#
# div
#
#
# div
#
#
# a
# HOME
# ul
#
#
# a
# CONTENT
# a
# Early Release
# ul
#
#
# a
# Featured
# ul
#
#
# a
# Current Issue
# ul
#
#
# a
# Issue Archive
# ul
#
#
# a
# Collections
# ul
#
#
# a
# Podcast
# ul
#
#
# ul
#
#
# a
# ALERTS
# ul
#
#
# a
# FOR AUTHORS
# a
# Information for Authors
# ul
#
#
# a
# Fees
# ul
#
#
# a
# Journal Clubs
# ul
#
#
# a
# eLetters
# ul
#
#
# a
# Submit
# ul
#
#
# ul
#
#
# a
# EDITORIAL BOARD
# ul
#
#
# a
# ABOUT
# a
# Overview
# ul
#
#
# a
# Advertise
# ul
#
#
# a
# For the Media
# ul
#
#
# a
# Rights and Permissions
# ul
#
#
# a
# Privacy Policy
# ul
#
#
# a
# Feedback
# ul
#
#
# ul
#
#
# a
# SUBSCRIBE
# ul
#
#
# div
#
#
# div
#
#
# div
#
#
# div
#
#
# div
#
#
# div
#
#
# div
#
#
# div
#
#
# div
#
#
# span
# User menu
# div
#
#
# div
#
#
# div
#
#
# div
#
#
# div
#
#
# div
#
#
# div
#
#
# a
# Log in
# ul
#
#
# a
#
# span
# My Cart
# ul
#
#
# div
#
#
# div
#
#
# div
#
#
# div
#
#
# div
#
#
# div
#
# div
#
#
# div
#
#
# div
#
#
# div
#
#
# div
#
#
# div
#
#
# div
#
#
# div
#
#
# span
# Search
# div
#
#
# div
#
#
# div
#
#
# div
#
#
# div
#
#
# div
#
#
# div
#
#
# label
# Search for this keyword
# div
#
#
# div
#
#
# div
#
#
# div
#
#
# div
#
#
# div
#
# div
#
#
# div
#
#
# div
#
#
# div
#
#
# ul
#
#
# a
# Advanced search
# ul
#
#
# div
#
# div
#
#
# div
#
#
# div
#
#
# div
#
#
# div
#
#
# div
#
#
# div
#
#
# div
#
#
# div
#
#
# div
#
#
# div
#
#
# div
#
#
# div
#
#
# div
#
#
# div
#
#
# div
#
#
# div
#
#
# div
#
#
# div
#
#
# div
#
# div
#
#
# div
#
#
# div
#
#
# div
#
#
# div
#
#
# div
#
#
# div
#
#
# div
#
# div
#
#
# div
#
# div
#
#
# div
#
#
# div
#
#
# div
#
#
# div
#
#
# div
#
#
# div
#
#
# div
#
#
# a
# Log in
# ul
#
#
# a
#
# span
# My Cart
# ul
#
#
# div
#
# div
#
#
# div
#
#
# div
#
#
# div
#
#
# div
#
#
# div
#
#
# div
#
#
# div
#
#
# div
#
#
# div
#
#
# div
#
#
# div
#
#
# div
#
#
# div
#
#
# div
#
#
# div
#
#
# div
#
#
# div
#
#
# div
#
#
# div
#
#
# div
#
#
# div
#
# div
#
#
# div
#
# div
#
#
# header
#
#
# div
#
#
# div
#
#
# div
#
#
# div
#
#
# div
#
#
# div
#
# div
#
#
# div
#
#
# div
#
#
# div
#
#
# div
#
#
# div
#
#
# div
#
#
# div
#
#
# div
#
#
# div
#
#
# div
#
#
# div
#
#
# div
#
#
# label
# Search for this keyword
# div
#
#
# div
#
#
# div
#
#
# div
#
#
# div
#
#
# div
#
# div
#
#
# div
#
#
# div
#
#
# div
#
#
# a
# Advanced Search
# div
#
# div
#
#
# div
#
#
# div
#
#
# div
#
#
# div
#
#
# div
#
#
# div
#
#
# div
#
#
# div
#
#
# div
#
#
# div
#
#
# div
#
#
# div
#
#
# div
#
#
# div
#
#
# div
#
#
# style
# .header-update-button {
#     padding: 4px;
#     border: 0px;
#     width: 100%;
#     margin-top: 20px;
#     border-radius: 8px; -webkit-border-radius: 8px; -moz-border-radius: 8px;
#     background-color: #104b7d;
#     font-size: 22px;
# }
# .header-update-button a {
#     color: #ffffff;
#     text-decoration: none;
# }
#
# div
#
#
# strong
# Submit a Manuscript
# div
#
#
# div
#
#
# div
#
#
# div
#
#
# div
#
#
# div
#
#
# div
#
#
# div
#
#
# div
#
#
# div
#
#
# div
#
# div
#
#
# div
#
# header
#
#
# div
#
#
# div
#
#
# div
#
#
# div
#
#
# div
#
#
# div
#
#
# a
# HOME
# ul
#
#
# a
# CONTENT
# a
# Early Release
# ul
#
#
# a
# Featured
# ul
#
#
# a
# Current Issue
# ul
#
#
# a
# Issue Archive
# ul
#
#
# a
# Collections
# ul
#
#
# a
# Podcast
# ul
#
#
# ul
#
#
# a
# ALERTS
# ul
#
#
# a
# FOR AUTHORS
# a
# Information for Authors
# ul
#
#
# a
# Fees
# ul
#
#
# a
# Journal Clubs
# ul
#
#
# a
# eLetters
# ul
#
#
# a
# Submit
# ul
#
#
# ul
#
#
# a
# EDITORIAL BOARD
# ul
#
#
# a
# ABOUT
# a
# Overview
# ul
#
#
# a
# Advertise
# ul
#
#
# a
# For the Media
# ul
#
#
# a
# Rights and Permissions
# ul
#
#
# a
# Privacy Policy
# ul
#
#
# a
# Feedback
# ul
#
#
# ul
#
#
# a
# SUBSCRIBE
# ul
#
#
# div
#
#
# div
#
#
# div
#
#
# div
#
# div
#
#
# div
#
#
# header
#
#
# div
#
#
# header
#
#
# div
#
#
# section
#
#
# div
#
#
# div
#
#
# div
#
#
# div
#
#
# div
#
#
# div
#
#
# div
#
#
# div
#
#
# div
#
#
# div
#
#
# div
#
#
# div
#
#
# div
#
#
# a
#
# span
# Previous
# span
# Next
# a
#
# div
#
# div
#
#
# div
#
#
# div
#
#
# div
#
#
# div
#
#
# span
# Articles
# div
#
#
# div
#
#
# em
# Caenorhabditis elegans rab-3
# h1
# Mutant Synapses Exhibit Impaired Function and Are Partially Depleted of Vesicles
# div
#
#
# span
# Michael L. Nonet
# span
# ,
# span
# Jane E. Staunton
# span
# ,
# span
# Michael P. Kilgard
# span
# ,
# span
# Tim Fergestad
# span
# ,
# span
# Erika Hartwieg
# span
# ,
# span
# H. Robert Horvitz
# span
# ,
# span
# Erik M. Jorgensen
# span
#  and
# span
# Barbara J. Meyer
# div
#
#
# span
# Journal of Neuroscience
# span
# 1 November 1997,
# span
# 17
# span
# (21)
# span
# 8061-8073;
# span
# DOI: https://doi.org/10.1523/JNEUROSCI.17-21-08061.1997
# div
#
#
# div
#
#
# div
#
#
# div
# Michael L. Nonet
# div
#
#
# span
# 1
# div
# Department of Molecular and Cell Biology, University of California, Berkeley, California 94720,
# div
#
#
# span
# 2
# div
# Department of Anatomy and Neurobiology, Washington University School of Medicine, St. Louis, Missouri 63110,
# a
# Find this author on Google Scholar
# a
# Find this author on PubMed
# a
# Search for this author on this site
# div
# Jane E. Staunton
# div
#
#
# span
# 2
# div
# Department of Anatomy and Neurobiology, Washington University School of Medicine, St. Louis, Missouri 63110,
# a
# Find this author on Google Scholar
# a
# Find this author on PubMed
# a
# Search for this author on this site
# div
# Michael P. Kilgard
# div
#
#
# span
# 1
# div
# Department of Molecular and Cell Biology, University of California, Berkeley, California 94720,
# a
# Find this author on Google Scholar
# a
# Find this author on PubMed
# a
# Search for this author on this site
# div
# Tim Fergestad
# div
#
#
# span
# 4
# div
# Department of Biology, University of Utah, Salt Lake City, Utah 84112
# a
# Find this author on Google Scholar
# a
# Find this author on PubMed
# a
# Search for this author on this site
# div
# Erika Hartwieg
# div
#
#
# span
# 3
# div
# Department of Biology and Howard Hughes Medical Institute, Massachusetts Institute of Technology, Cambridge, Massachusetts 02139, and
# a
# Find this author on Google Scholar
# a
# Find this author on PubMed
# a
# Search for this author on this site
# div
# H. Robert Horvitz
# div
#
#
# span
# 3
# div
# Department of Biology and Howard Hughes Medical Institute, Massachusetts Institute of Technology, Cambridge, Massachusetts 02139, and
# a
# Find this author on Google Scholar
# a
# Find this author on PubMed
# a
# Search for this author on this site
# div
# Erik M. Jorgensen
# div
#
#
# span
# 4
# div
# Department of Biology, University of Utah, Salt Lake City, Utah 84112
# a
# Find this author on Google Scholar
# a
# Find this author on PubMed
# a
# Search for this author on this site
# div
# Barbara J. Meyer
# div
#
#
# span
# 1
# div
# Department of Molecular and Cell Biology, University of California, Berkeley, California 94720,
# a
# Find this author on Google Scholar
# a
# Find this author on PubMed
# a
# Search for this author on this site
# div
#
# div
#
#
# div
#
#
# div
#
#
# div
#
#
# div
#
#
# div
#
# div
#  /.panel-row-wrapper
# div
#
#
# div
#
#
# div
#
#
# div
#
#
# div
#
#
# div
#
#
# a
# Article
# a
# Figures & Data
# a
# Info & Metrics
# a
# eLetters
# a
#  PDF
# div
#
# div
#
#
# div
#
#
# div
#
#
# div
#
#
# div
#
#
# div
#
#
# div
#
#
# div
#
#
# h2
# Abstract
# p
# Rab molecules regulate vesicular trafficking in many different exocytic and endocytic transport pathways in eukaryotic cells. In neurons, rab3 has been proposed to play a crucial role in regulating synaptic vesicle release. To elucidate the role of rab3 in synaptic transmission, we isolated and characterized
# em
# Caenorhabditis elegans rab-3
# p
#  mutants. Similar to the mouse rab3A mutants, these mutants survived and exhibited only mild behavioral abnormalities. In contrast to the mouse mutants, synaptic transmission was perturbed in these animals. Extracellular electrophysiological recordings revealed that synaptic transmission in the pharyngeal nervous system was impaired. Furthermore,
# em
# rab-3
# p
#  animals were resistant to the acetylcholinesterase inhibitor aldicarb, suggesting that cholinergic transmission was generally depressed. Last, synaptic vesicle populations were redistributed in
# em
# rab-3
# p
#  mutants. In motor neurons, vesicle populations at synapses were depleted to 40% of normal levels, whereas in intersynaptic regions of the axon, vesicle populations were elevated. On the basis of the morphological defects at neuromuscular junctions, we postulate that RAB-3 may regulate recruitment of vesicles to the active zone or sequestration of vesicles near release sites.
# a
# small GTP-binding proteins
# a
# exocytosis
# a
# rab3
# a
# synaptic vesicle proteins
# em
# Caenorhabditis elegans
# a
# mutants
# a
# View Full Text
# div
#
# div
#
#
# div
#
#
# div
#
#
# div
#
#
# div
#
#
# div
#
# div
#
#
# div
#
#
# div
#
#
# div
#
#
# a
#  Back to top
# div
#
# div
#
#
# div
#
#
# div
#
#
# div
#
#
# div
#
#
# div
#
#
# div
#
#
# div
#
#
# h2
# In this issue
# div
#
#
# div
#
#
# div
#
#
# div
#
#
# div
#
#
# div
#
#
# div
#
#
# div
#
#
# div
#
#
# span
# Journal of Neuroscience
# div
#
#
# span
# Vol. 17
# div
# ,
# span
# Issue 21
# div
# 1 Nov 1997
# div
#
#
# a
# Table of Contents
# a
# Index by author
# div
#
#
# div
#
#
# div
#
# div
#
#
# div
#
#
# div
#
#
# div
#
#
# div
#
#
# div
#
#
# div
#
#
# div
#
#
# div
#
#
# div
#
#
# div
#
#
# div
#
#
# div
#
#
# div
#
#
# div
#
#
# a
#
# span
# Email
# div
#
#
# div
#
#
# div
#
#
# div
#
#
# div
#
#
# p
# Thank you for sharing this Journal of Neuroscience article.
# p
# NOTE: We request your email address only to inform the recipient that it was you who recommended this article, and that it is not junk mail. We do not retain these email addresses.
# div
#
#
# div
#
#
# div
#
#
# label
# Your Email
# span
# *
# div
#
#
# div
#
#
# div
#
#
# div
#
#
# label
# Your Name
# span
# *
# div
#
#
# div
#
#
# div
#
#
# div
#
#
# label
# Send To
# span
# *
# div
#
#
# div
#
#
# div
# Enter multiple addresses on separate lines or separate them with commas.
# div
#
#
# div
#
#
# div
#
#
# label
# You are going to email the following
# div
#
#
# a
# Caenorhabditis elegans rab-3 Mutant Synapses Exhibit Impaired Function and Are Partially Depleted of Vesicles
# div
#
#
# div
#
#
# div
#
#
# label
# Message Subject
# div
#
#  (Your Name) has forwarded a page to you from Journal of Neuroscience
#
# div
#
#
# div
#
#
# label
# Message Body
# div
#
#  (Your Name) thought you would be interested in this article in Journal of Neuroscience.
#
# div
#
#
# div
#
#
# label
# Your Personal Message
# div
#
#
# div
#
#
# div
#
#
# div
#
#
# div
#
#
# div
#
#
# div
#
#
# div
#
#
# span
# CAPTCHA
# div
# This question is for testing whether or not you are a human visitor and to prevent automated spam submissions.
# div
#
#
# div
#
#
# div
#
#
# div
#
#
# div
#
# div
#
#
# div
#
#
# div
#
#
# div
#
#
# div
#
#
# div
#
# div
#
#
# div
#
#
# div
#
#
# div
#
#
# a
#
# span
# Print
# div
#
# div
#
#
# div
#
#
# div
#
#
# div
#
#
# a
#
# span
# View Full Page PDF
# div
#
# div
#
#
# div
#
#
# div
#
#
# div
#
#
# a
#
# span
# Citation Tools
# div
#
#
# div
#
#
# div
#
#
# div
#
#
# div
#
#
# div
#
#
# div
#
#
# em
# Caenorhabditis elegans rab-3
# div
# Mutant Synapses Exhibit Impaired Function and Are Partially Depleted of Vesicles
# div
#
#
# span
# Michael L. Nonet
# span
# ,
# span
# Jane E. Staunton
# span
# ,
# span
# Michael P. Kilgard
# span
# ,
# span
# Tim Fergestad
# span
# ,
# span
# Erika Hartwieg
# span
# ,
# span
# H. Robert Horvitz
# span
# ,
# span
# Erik M. Jorgensen
# span
# ,
# span
# Barbara J. Meyer
# div
#
#
# span
# Journal of Neuroscience
# span
# 1 November 1997,
# span
# 17
# span
# (21)
# span
# 8061-8073;
# span
# DOI:
# span
#  10.1523/JNEUROSCI.17-21-08061.1997
# div
#
#
# div
#
#
# div
#
# div
#
#
# div
#
#
# h2
# Citation Manager Formats
# div
#
#
# div
#
#
# a
# BibTeX
# a
# Bookends
# a
# EasyBib
# a
# EndNote (tagged)
# a
# EndNote 8 (xml)
# a
# Medlars
# a
# Mendeley
# a
# Papers
# a
# RefWorks Tagged
# a
# Ref Manager
# a
# RIS
# a
# Zotero
# div
#
# div
#
#
# div
#
#
# div
#
#
# div
#
#
# div
#
#
# div
#
#
# div
#
#
# div
#
#
# div
#
# div
#
#
# div
#
#
# div
#
#
# div
#
#
# a
#
# span
# Respond to this article
# div
#
# div
#
#
# div
#
#
# div
#
#
# div
#
#
# div
#
#
# div
#
#
# div
#
#
# div
#
#
# div
#
#
# div
#
#
# i
#
# a
#
# span
# Request Permissions
# div
#
# div
#
#
# div
#
#
# div
#
#
# div
#
#
# div
#
#
# div
#
#
# div
#
#
# div
#
#
# div
#
#
# div
#
#
# div
#
#
# div
#
#
# div
#
#
# div
#
#
# div
#
#
# div
#
#
# a
#
# span
# Share
# div
#
# div
#
#
# div
#
#
# div
#
#
# div
#
#
# div
#
#
# div
#
#
# div
#
#
# div
#
#
# div
#
#
# em
# Caenorhabditis elegans rab-3
# div
# Mutant Synapses Exhibit Impaired Function and Are Partially Depleted of Vesicles
# div
#
#
# span
# Michael L. Nonet
# span
# ,
# span
# Jane E. Staunton
# span
# ,
# span
# Michael P. Kilgard
# span
# ,
# span
# Tim Fergestad
# span
# ,
# span
# Erika Hartwieg
# span
# ,
# span
# H. Robert Horvitz
# span
# ,
# span
# Erik M. Jorgensen
# span
# ,
# span
# Barbara J. Meyer
# div
#
#
# span
# Journal of Neuroscience
# span
# 1 November 1997,
# span
# 17
# span
# (21)
# span
# 8061-8073;
# span
# DOI:
# span
#  10.1523/JNEUROSCI.17-21-08061.1997
# div
#
#
# div
#
#
# div
#
# div
#
#
# div
#
#
# div
#
#
# div
#
#
# div
#
#
# span
#
#
# label
# Share This Article:
# span
#
#
# div
#
#
# span
#
#
# span
#
#
# div
#
#
# span
#
#
# button
# Copy
# span
#
#
# div
#
#
# div
#
#
# div
#
#
# div
#
#
# div
#
#
# div
#
#
# div
#
# div
#
# div
#
# div
#
# div
#
# div
#
# div
#
# div
#
# div
#
#
# div
#
#
# div
#
#
# div
#
#
# div
#
#
# div
#
#
# div
#
#
# div
#
#
# div
#
#
# span
# Tweet Widget
# span
# Facebook Like
# span
# Google Plus One
# div
#
# div
#
#
# div
#
#
# div
#
#
# div
#
#
# div
#
#
# div
#
# div
#  /.panel-row-wrapper
# div
#
#
# div
#
#
# div
#
#
# div
#
#
# div
#
#
# h2
# Jump to section
# div
#
#
# div
#
#
# a
# Article
# a
# Abstract
# a
# MATERIALS AND METHODS
# a
# RESULTS
# a
# DISCUSSION
# a
# Footnotes
# a
# REFERENCES
# a
# Figures & Data
# a
# Info & Metrics
# a
# eLetters
# a
#  PDF
# div
#
# div
#
#
# div
#
#
# div
#
#
# h2
# Keywords
# div
#
#
# div
#
#
# span
# small GTP-binding proteins
# span
# exocytosis
# span
# rab3
# span
# synaptic vesicle proteins
# span
# Caenorhabditis elegans
# span
# mutants
# div
#
# div
#
#
# div
#
#
# div
#
#
# h2
# Responses to this article
# div
#
#
# div
#
#
# div
#
#
# div
#
#
# div
#
#
# div
#
#
# div
#
#
# div
#
#
# a
#
# span
# Respond to this article
# div
#
# div
#
#
# div
#
#
# div
#
#
# div
#
#
# div
#
#
# div
#
# div
#  /.panel-row-wrapper
# div
#
#
# div
#
#
# div
#
#
# div
#
#
# div
#
#
# h3
# Jump to comment:
# div
#
#
# div
#
#     No eLetters have been published for this article.
# div
#
#
# div
#
#
# div
#
#
# div
#
#
# div
#
#
# div
#
# div
#  /.panel-row-wrapper
# div
#
#
# div
#
#
# div
#
#
# div
#
#
# div
#
#
# div
#
#
# div
#
#
# div
#
#
# h3
#  Related Articles
# h3
#  Cited By...
# h3
#  More in this TOC Section
# div
#
#
# span
# Choice Behavior Guided by Learned, But Not Innate, Taste Aversion Recruits the Orbitofrontal Cortex
# div
#
#
# div
#
#
# div
#
#
# span
# Maturation of Spontaneous Firing Properties after Hearing Onset in Rat Auditory Nerve Fibers: Spontaneous Rates, Refractoriness, and Interfiber Correlations
# div
#
#
# div
#
#
# div
#
#
# span
# Insulin Treatment Prevents Neuroinflammation and Neuronal Injury with Restored Neurobehavioral Function in Models of HIV/AIDS Neurodegeneration
# div
#
#
# div
#
#
# a
# Show more
# span
# Articles
# div
#
#
# div
#
#
# div
#
#
# div
#
#
# div
#
#
# div
#
#
# div
#
#
# div
#
#
# div
#
#
# div
#
#
# div
#
#
# div
#
#
# div
#
#
# div
#
# div
#
#
# div
#
#
# div
#
#
# div
#
#
# div
#
#
# div
#
#
# div
#
#
# div
#
#
# div
#
#
# div
#
#
# div
#
#
# div
#
# div
#
#
# div
#
#
# div
#
#
# div
#
#
# div
#
#
# div
#
# div
#  /.panel-row-wrapper
# div
#
#
# div
#
#
# div
#
#
# div
#
#
# div
#
# div
#
#
# div
#
# section
#
#
# div
#
#
# footer
#
#
# div
#
#
# div
#
#
# div
#
#
# div
#
#
# div
#
#
# div
#
#
# a
# Home
# ul
#
#
# a
# Alerts
# ul
#
#
# div
#
# div
#
#
# div
#
#
# div
#
#
# div
#
#
# div
#
#
# a
#
# span
# Visit Society for Neuroscience on Facebook
# ul
#
#
# a
#
# span
# Follow Society for Neuroscience on Twitter
# ul
#
#
# a
#
# span
# Follow Society for Neuroscience on LinkedIn
# ul
#
#
# a
#
# span
# Visit Society for Neuroscience on Youtube
# ul
#
#
# a
#
# span
# Follow our RSS feeds
# ul
#
#
# div
#
# div
#
#
# div
#
#
# div
#
# div
#
#
# div
#
#
# div
#
#
# section
#
#
# div
#
#
# h2
# Content
# div
#
#
# div
#
#
# a
# Early Release
# ul
#
#
# a
# Current Issue
# ul
#
#
# a
# Issue Archive
# ul
#
#
# a
# Collections
# ul
#
#
# div
#
# div
#
#
# section
#
#
# div
#
# div
#
#
# div
#
#
# div
#
#
# section
#
#
# div
#
#
# h2
# Information
# div
#
#
# div
#
#
# a
# For Authors
# ul
#
#
# a
# For Advertisers
# ul
#
#
# a
# For the Media
# ul
#
#
# a
# For Subscribers
# ul
#
#
# div
#
# div
#
#
# section
#
#
# div
#
# div
#
#
# div
#
#
# div
#
#
# section
#
#
# div
#
#
# h2
#  About
# div
#
#
# div
#
#
# a
# About the Journal
# ul
#
#
# a
# Editorial Board
# ul
#
#
# a
# Privacy Policy
# ul
#
#
# a
# Contact
# ul
#
#
# div
#
# div
#
#
# section
#
#
# div
#
# div
#
#
# div
#
# footer
#
#
# div
#
#
# div
#
#
# div
#
#
# div
#
#
# div
#
#
# div
#
#
# div
#
#
# div
#
#
# div
#
#
# div
#
#
# div
#
#
# div
#
#
# div
#
#
# div
#
#
# div
#
#
# div
#
#
# p
# Copyright © 2022 by the Society for Neuroscience.
# p
#
#
# em
# JNeurosci
# p
#  Online ISSN: 1529-2401
# div
#
#
# p
# The ideas and opinions expressed in
# em
# JNeurosci
# p
#  do not necessarily reflect those of SfN or the
# em
# JNeurosci
# p
#  Editorial Board. Publication of an advertisement or other product mention in
# em
# JNeurosci
# p
#  should not be construed as an endorsement of the manufacturer’s claims. SfN does not assume any responsibility for any injury and/or damage to persons or property arising from or related to any use of any material contained in
# em
# JNeurosci
# p
# .
# div
#
#
# div
#
#
# div
#
#
# div
#
#
# div
#
#
# div
#
#
# div
#
#
# div
#
#
# div
#
#
# div
#  Google Code for Remarketing Tag
# script
#
# /* <![CDATA[ */
# var google_conversion_id = 952157035;
# var google_custom_params = window.google_tag_params;
# var google_remarketing_only = true;
# /* ]]> */
#
# script
#
#
# noscript
#
#
# div
#
#
# div
#
#
# noscript
#
#
# div
#
# div
#
#
# div
#
#
# div
#
#
# div
#
#
# div
#
#
# div
#
#
# div
#
#
# div
#
# div
#
#
# div
#
# footer
#
#
# div
#
# body
#
# div
#
#
# div
#
#
# div
#
#
# body
#
#
# body
#
#
# body
#
#
# script
#
# <!--//--><![CDATA[//><!--
# function euCookieComplianceLoadScripts() {}
# //--><!]]>
#
# body
#
#
# script
#
# <!--//--><![CDATA[//><!--
# var eu_cookie_compliance_cookie_name = "";
# //--><!]]>
#
# body
#
#
# html
#
#
# [document]

# %%
from urllib.request import Request, urlopen
import re

session = HTMLSession()
response=session.get(links[3])

soup = BeautifulSoup(response, "html.parser")

html_text = soup.get_text()

f = open("html_text.txt", "w")         # Creating html_text.txt File

for line in html_text:
    f.write(line)
f.close()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [31], in <cell line: 7>()
#       4 session = HTMLSession()
#       5 response=session.get(links[3])
# ----> 7 soup = BeautifulSoup(response, "html.parser")
#       9 html_text = soup.get_text()
#      11 f = open("html_text.txt", "w")         # Creating html_text.txt File
#
# File ~/miniforge3/envs/annotations/lib/python3.10/site-packages/bs4/__init__.py:313, in BeautifulSoup.__init__(self, markup, features, builder, parse_only, from_encoding, exclude_encodings, element_classes, **kwargs)
#     311 if hasattr(markup, 'read'):        # It's a file-type object.
#     312     markup = markup.read()
# --> 313 elif len(markup) <= 256 and (
#     314         (isinstance(markup, bytes) and not b'<' in markup)
#     315         or (isinstance(markup, str) and not '<' in markup)
#     316 ):
#     317     # Issue warnings for a couple beginner problems
#     318     # involving passing non-markup to Beautiful Soup.
#     319     # Beautiful Soup will still parse the input as markup,
#     320     # since that is sometimes the intended behavior.
#     321     if not self._markup_is_url(markup):
#     322         self._markup_resembles_filename(markup)
#
# TypeError: object of type 'HTMLResponse' has no len()

# %%
# Out:
# <_io.TextIOWrapper name='html_text.txt' mode='w' encoding='UTF-8'>

# %%
sci_hub_links = []
for link in links:
    session = HTMLSession()
    response=session.get(f'https://sci-hub.se/{link}')
    paper_info = BeautifulSoup(response.text,'html.parser')
    pdf_link = paper_info.select('embed')
    try:
        pdf_link = pdf_link[0].get('src')
    except:
        print(f'{link} no encontrado')
    sci_hub_links.append(pdf_link)
# Out:
# https://www.sciencedirect.com/science/article/pii/S002192581882364X no encontrado
# https://www.ncbi.nlm.nih.gov/pmc/articles/PMC331846/ no encontrado
# https://www.life-science-alliance.org/content/2/1/e201800131.abstract no encontrado
# https://journals.plos.org/plosone/article?id=10.1371/journal.pone.0160838 no encontrado

# %%
sci_hub_links
# Out:
# ['//moscow.sci-hub.se/4091/25d3a35bbb4b3f7e8465d8b22eb5b27c/overmeyer1998.pdf#navpanes=0&view=FitH',
#  '//moscow.sci-hub.se/4839/bd73205ac1dfeb12c510a7a629f7a67c/nikoshkov2014.pdf#navpanes=0&view=FitH',
#  '//zero.sci-hub.se/3805/442dbaa82c97e35c0c21a4f069fe008a/romero2013.pdf#navpanes=0&view=FitH',
#  '//zero.sci-hub.se/7010/e0a3b0d715cc846d2089addc680526e6/10.3389@fcimb.2017.00431.pdf#navpanes=0&view=FitH',
#  [],
#  [],
#  '//zero.sci-hub.se/5900/1d5c0c8b1d3cf8a8d112bce04847a240/white2016.pdf#navpanes=0&view=FitH',
#  '//moscow.sci-hub.se/4666/966f10dfd063a124031f53f7e1c2fc10/hutt2008.pdf#navpanes=0&view=FitH',
#  [],
#  []]

# %%
for link in sci_hub_links:
    try:
        response=session.get('zero.sci-hub.se/6368/1e32bd63b94732a95dc379d69f2817e6/kakuta2017.pdf#navpanes=0&view=FitH')
    except:
        print('no hay porque')
    break

# %%
response=session.get('http://zero.sci-hub.se/6368/1e32bd63b94732a95dc379d69f2817e6/kakuta2017.pdf#navpanes=0&view=FitH')

# %%
#paper_doc = BeautifulSoup(response.text,'html.parser')

pdf = open("s.pdf", 'wb')
pdf.write(response.content)
pdf.close()
#print("File ", i, " downloaded")

# %%
from PyPDF2 import PdfFileReader

with open(response, 'rb') as f:
    pdf = PdfFileReader(f)
    information = pdf.getDocumentInfo()
    number_of_pages = pdf.getNumPages()

# %%
information.title
